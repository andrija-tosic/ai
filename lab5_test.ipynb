# %%
from lab5 import solve, pprint_board
from pprint import pprint

N = 8

free_graph = {
    i: {x for x in range(N)} for i in range(N)
}

# pprint(free_graph)

res = solve(N, 0, free_graph, [], [])

pprint_board(N, res)

pprint(res)
# Out:
# [Q][x][x][x][x][x][x][x]
# [x][x][ ][ ][ ][ ][ ][ ]
# [x][ ][x][ ][ ][ ][ ][ ]
# [x][ ][ ][x][ ][ ][ ][ ]
# [x][ ][ ][ ][x][ ][ ][ ]
# [x][ ][ ][ ][ ][x][ ][ ]
# [x][ ][ ][ ][ ][ ][x][ ]
# [x][ ][ ][ ][ ][ ][ ][x]
#
# [(0, 0)]
# [x][x][x][x][x][x][x][x]
# [x][x][Q][x][x][x][x][x]
# [x][x][x][x][ ][ ][ ][ ]
# [x][ ][x][x][x][ ][ ][ ]
# [x][ ][x][ ][x][x][ ][ ]
# [x][ ][x][ ][ ][x][x][ ]
# [x][ ][x][ ][ ][ ][x][x]
# [x][ ][x][ ][ ][ ][ ][x]
#
# [(0, 0), (1, 2)]
# [x][x][x][x][x][x][x][x]
# [x][x][x][x][x][x][x][x]
# [x][x][x][x][Q][x][x][x]
# [x][ ][x][x][x][x][ ][ ]
# [x][ ][x][ ][x][x][x][ ]
# [x][x][x][ ][x][x][x][x]
# [x][ ][x][ ][x][ ][x][x]
# [x][ ][x][ ][x][ ][ ][x]
#
# [(0, 0), (1, 2), (2, 4)]
# [x][x][x][x][x][x][x][x]
# [x][x][x][x][x][x][x][x]
# [x][x][x][x][x][x][x][x]
# [x][x][x][x][x][x][ ][ ]
# [x][ ][x][x][x][x][x][ ]
# [x][x][x][Q][x][x][x][x]
# [x][ ][x][x][x][ ][x][x]
# [x][x][x][x][x][x][ ][x]
#
# [(0, 0), (1, 2), (2, 4), (5, 3)]
# [x][x][x][x][x][x][x][x]
# ...
